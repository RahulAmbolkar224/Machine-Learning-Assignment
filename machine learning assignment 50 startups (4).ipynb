# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = 'C:\Top Mentor Datasets'

# %%
os.chdir(path)

# %%
pwd
# Out:
# 'C:\\Top Mentor Datasets'

# %%
data = pd.read_csv('50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
 df = data.copy()
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# # R & D Spend,Administration and Marketing Spend wise  Profit Linear Regression

# %%
x= df['R&D Spend'].values
y= df['Profit'].values

# %%
x = x.reshape(-1,1)
x
# Out:
# array([[165349.2 ],
#        [162597.7 ],
#        [153441.51],
#        [144372.41],
#        [142107.34],
#        [131876.9 ],
#        [134615.46],
#        [130298.13],
#        [120542.52],
#        [123334.88],
#        [101913.08],
#        [100671.96],
#        [ 93863.75],
#        [ 91992.39],
#        [119943.24],
#        [114523.61],
#        [ 78013.11],
#        [ 94657.16],
#        [ 91749.16],
#        [ 86419.7 ],
#        [ 76253.86],
#        [ 78389.47],
#        [ 73994.56],
#        [ 67532.53],
#        [ 77044.01],
#        [ 64664.71],
#        [ 75328.87],
#        [ 72107.6 ],
#        [ 66051.52],
#        [ 65605.48],
#        [ 61994.48],
#        [ 61136.38],
#        [ 63408.86],
#        [ 55493.95],
#        [ 46426.07],
#        [ 46014.02],
#        [ 28663.76],
#        [ 44069.95],
#        [ 20229.59],
#        [ 38558.51],
#        [ 28754.33],
#        [ 27892.92],
#        [ 23640.93],
#        [ 15505.73],
#        [ 22177.74],
# ...

# %%
y = y.reshape(-1,1)
y
# Out:
# array([[192261.83],
#        [191792.06],
#        [191050.39],
#        [182901.99],
#        [166187.94],
#        [156991.12],
#        [156122.51],
#        [155752.6 ],
#        [152211.77],
#        [149759.96],
#        [146121.95],
#        [144259.4 ],
#        [141585.52],
#        [134307.35],
#        [132602.65],
#        [129917.04],
#        [126992.93],
#        [125370.37],
#        [124266.9 ],
#        [122776.86],
#        [118474.03],
#        [111313.02],
#        [110352.25],
#        [108733.99],
#        [108552.04],
#        [107404.34],
#        [105733.54],
#        [105008.31],
#        [103282.38],
#        [101004.64],
#        [ 99937.59],
#        [ 97483.56],
#        [ 97427.84],
#        [ 96778.92],
#        [ 96712.8 ],
#        [ 96479.51],
#        [ 90708.19],
#        [ 89949.14],
#        [ 81229.06],
#        [ 81005.76],
#        [ 78239.91],
#        [ 77798.83],
#        [ 71498.49],
#        [ 69758.98],
#        [ 65200.33],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lin= LinearRegression()

# %%
lin.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color = 'blue')
plt.plot(x,lin.predict(x),color = 'red')

# %% [markdown]
# # Administration and Profit Linear Regression

# %%
x1 = df['Administration'].values
x1 = x1.reshape(-1,1)
x1
# Out:
# array([[136897.8 ],
#        [151377.59],
#        [101145.55],
#        [118671.85],
#        [ 91391.77],
#        [ 99814.71],
#        [147198.87],
#        [145530.06],
#        [148718.95],
#        [108679.17],
#        [110594.11],
#        [ 91790.61],
#        [127320.38],
#        [135495.07],
#        [156547.42],
#        [122616.84],
#        [121597.55],
#        [145077.58],
#        [114175.79],
#        [153514.11],
#        [113867.3 ],
#        [153773.43],
#        [122782.75],
#        [105751.03],
#        [ 99281.34],
#        [139553.16],
#        [144135.98],
#        [127864.55],
#        [182645.56],
#        [153032.06],
#        [115641.28],
#        [152701.92],
#        [129219.61],
#        [103057.49],
#        [157693.92],
#        [ 85047.44],
#        [127056.21],
#        [ 51283.14],
#        [ 65947.93],
#        [ 82982.09],
#        [118546.05],
#        [ 84710.77],
#        [ 96189.63],
#        [127382.3 ],
#        [154806.14],
# ...

# %%
lin1 = LinearRegression()

# %%
lin1.fit(x1,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x1,y,color = ('green'))
plt.plot(x1,lin1.predict(x1),color = 'red')

# %% [markdown]
# # Marketing spend and Profit Linear Regression

# %%
x2 = df['Marketing Spend'].values
x2 = x2.reshape(-1,1)
x2
# Out:
# array([[471784.1 ],
#        [443898.53],
#        [407934.54],
#        [383199.62],
#        [366168.42],
#        [362861.36],
#        [127716.82],
#        [323876.68],
#        [311613.29],
#        [304981.62],
#        [229160.95],
#        [249744.55],
#        [249839.44],
#        [252664.93],
#        [256512.92],
#        [261776.23],
#        [264346.06],
#        [282574.31],
#        [294919.57],
#        [     0.  ],
#        [298664.47],
#        [299737.29],
#        [303319.26],
#        [304768.73],
#        [140574.81],
#        [137962.62],
#        [134050.07],
#        [353183.81],
#        [118148.2 ],
#        [107138.38],
#        [ 91131.24],
#        [ 88218.23],
#        [ 46085.25],
#        [214634.81],
#        [210797.67],
#        [205517.64],
#        [201126.82],
#        [197029.42],
#        [185265.1 ],
#        [174999.3 ],
#        [172795.67],
#        [164470.71],
#        [148001.11],
#        [ 35534.17],
#        [ 28334.72],
# ...

# %%
lin2 = LinearRegression()

# %%
lin2.fit(x2,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x2,y,color = 'orange')
plt.plot(x2,lin2.predict(x2),color = 'brown')

# %% [markdown]
# # State wise Profit

# %%
state = df[['State','Profit']]
state
# Out:
#          State     Profit
# 0     New York  192261.83
# 1   California  191792.06
# 2      Florida  191050.39
# 3     New York  182901.99
# 4      Florida  166187.94
# 5     New York  156991.12
# 6   California  156122.51
# 7      Florida  155752.60
# 8     New York  152211.77
# 9   California  149759.96
# 10     Florida  146121.95
# 11  California  144259.40
# 12     Florida  141585.52
# 13  California  134307.35
# 14     Florida  132602.65
# 15    New York  129917.04
# 16  California  126992.93
# 17    New York  125370.37
# 18     Florida  124266.90
# 19    New York  122776.86
# 20  California  118474.03
# 21    New York  111313.02
# 22     Florida  110352.25
# 23     Florida  108733.99
# 24    New York  108552.04
# 25  California  107404.34
# 26     Florida  105733.54
# 27    New York  105008.31
# 28     Florida  103282.38
# 29    New York  101004.64
# 30     Florida   99937.59
# 31    New York   97483.56
# 32  California   97427.84
# 33     Florida   96778.92
# ...

# %%
sns.barplot(x = 'State',y = 'Profit',data = state)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %% [markdown]
# # State wise R&D Spend

# %%
RnD = df[['State','R&D Spend']]
RnD
# Out:
#          State  R&D Spend
# 0     New York  165349.20
# 1   California  162597.70
# 2      Florida  153441.51
# 3     New York  144372.41
# 4      Florida  142107.34
# 5     New York  131876.90
# 6   California  134615.46
# 7      Florida  130298.13
# 8     New York  120542.52
# 9   California  123334.88
# 10     Florida  101913.08
# 11  California  100671.96
# 12     Florida   93863.75
# 13  California   91992.39
# 14     Florida  119943.24
# 15    New York  114523.61
# 16  California   78013.11
# 17    New York   94657.16
# 18     Florida   91749.16
# 19    New York   86419.70
# 20  California   76253.86
# 21    New York   78389.47
# 22     Florida   73994.56
# 23     Florida   67532.53
# 24    New York   77044.01
# 25  California   64664.71
# 26     Florida   75328.87
# 27    New York   72107.60
# 28     Florida   66051.52
# 29    New York   65605.48
# 30     Florida   61994.48
# 31    New York   61136.38
# 32  California   63408.86
# 33     Florida   55493.95
# ...

# %%
sns.lineplot(x = 'State',y = 'R&D Spend',data = RnD)
# Out:
# <AxesSubplot:xlabel='State', ylabel='R&D Spend'>
